# %%
import pandas as pd

# %%
FinanceData = pd.read_csv("aged_debtor_facts_v2_2024__2024-04-12_18-19-25.csv")

# %%
FinanceData.head()
# Out:
#   demarcation_code period_code  customer_group_code  bad_amount  badi_amount  \
# 0              BUF     2024M01                  NaN           0            0
# 1              BUF     2024M01                  NaN           0     15168131
# 2              BUF     2024M01                  NaN           0     42480113
# 3              BUF     2024M01                  NaN           0     35889383
# 4              BUF     2024M01                  NaN           0      8016947
#
#     g1_amount  l1_amount  l120_amount  l150_amount  l180_amount  l30_amount  \
# 0           0          0            0            0            0           0
# 1  1535315627  193153551     39303853     37813596     34168987    80774212
# 2   391769777   90101408     20257526     18595615     16150805   148639203
# 3   749661261  164124472     35975278     32609167     27235043   241985985
# 4   363135730   61170379     12651025     11708248     10428795    63743098
#
# ...
